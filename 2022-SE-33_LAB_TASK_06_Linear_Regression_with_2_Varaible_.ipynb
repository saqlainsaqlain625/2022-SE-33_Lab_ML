# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("taxi_trip_pricing.csv")

# %%
df
# Out:
#      Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 0               19.35     Morning     Weekday              3.0
# 1               47.59   Afternoon     Weekday              1.0
# 2               36.87     Evening     Weekend              1.0
# 3               30.33     Evening     Weekday              4.0
# 4                 NaN     Evening     Weekday              3.0
# ..                ...         ...         ...              ...
# 995              5.49   Afternoon     Weekend              4.0
# 996             45.95       Night     Weekday              4.0
# 997              7.70     Morning     Weekday              3.0
# 998             47.56     Morning     Weekday              1.0
# 999             22.85     Morning     Weekend              3.0
#
#     Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                  Low   Clear       3.56         0.80             0.32
# 1                 High   Clear        NaN         0.62             0.43
# 2                 High   Clear       2.70         1.21             0.15
# 3                  Low     NaN       3.48         0.51             0.15
# 4                 High   Clear       2.93         0.63             0.32
# ..                 ...     ...        ...          ...              ...
# 995             Medium   Clear       2.39         0.62             0.49
# 996             Medium   Clear       3.12         0.61              NaN
# 997                Low    Rain       2.08         1.78              NaN
# 998                Low   Clear       2.67         0.82             0.17
# 999             Medium   Clear       4.34          NaN             0.23
#
#      Trip_Duration_Minutes  Trip_Price
# 0                    53.82     36.2624
# 1                    40.57         NaN
# 2                    37.27     52.9032
# 3                   116.81     36.4698
# 4                    22.64     15.6180
# ..                     ...         ...
# 995                  58.39     34.4049
# 996                  61.96     62.1295
# 997                  54.18     33.1236
# 998                 114.94     61.2090
# 999                  29.69     45.4437
#
# [1000 rows x 11 columns]

# %%
df.describe()
# Out:
#        Trip_Distance_km  Passenger_Count   Base_Fare  Per_Km_Rate  \
# count        950.000000       950.000000  950.000000   950.000000
# mean          27.070547         2.476842    3.502989     1.233316
# std           19.905300         1.102249    0.870162     0.429816
# min            1.230000         1.000000    2.010000     0.500000
# 25%           12.632500         1.250000    2.730000     0.860000
# 50%           25.830000         2.000000    3.520000     1.220000
# 75%           38.405000         3.000000    4.260000     1.610000
# max          146.067047         4.000000    5.000000     2.000000
#
#        Per_Minute_Rate  Trip_Duration_Minutes  Trip_Price
# count       950.000000             950.000000  951.000000
# mean          0.292916              62.118116   56.874773
# std           0.115592              32.154406   40.469791
# min           0.100000               5.010000    6.126900
# 25%           0.190000              35.882500   33.742650
# 50%           0.290000              61.860000   50.074500
# 75%           0.390000              89.055000   69.099350
# max           0.500000             119.840000  332.043689

# %%
df[df["Trip_Distance_km"].isnull()]
# Out:
#      Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 4                 NaN     Evening     Weekday              3.0
# 10                NaN     Morning     Weekday              4.0
# 84                NaN       Night     Weekday              1.0
# 87                NaN         NaN     Weekday              1.0
# 95                NaN     Morning     Weekend              1.0
# 111               NaN     Morning     Weekday              2.0
# 134               NaN   Afternoon     Weekend              3.0
# 137               NaN         NaN         NaN              3.0
# 142               NaN   Afternoon     Weekend              4.0
# 166               NaN     Evening     Weekday              2.0
# 191               NaN   Afternoon     Weekend              2.0
# 196               NaN       Night     Weekday              2.0
# 197               NaN       Night     Weekend              3.0
# 234               NaN   Afternoon     Weekday              3.0
# 269               NaN     Morning     Weekday              3.0
# 282               NaN   Afternoon     Weekday              1.0
# 327               NaN     Evening     Weekday              3.0
# 344               NaN     Evening         NaN              NaN
# 357               NaN   Afternoon     Weekday              3.0
# 366               NaN     Evening     Weekday              4.0
# 401               NaN     Morning         NaN              1.0
# 404               NaN   Afternoon     Weekday              2.0
# 417               NaN     Morning     Weekday              3.0
# 424               NaN       Night     Weekday              1.0
# 428               NaN   Afternoon     Weekday              NaN
# 438               NaN     Morning     Weekday              2.0
# 439               NaN   Afternoon     Weekday              4.0
# 446               NaN   Afternoon     Weekday              1.0
# 470               NaN   Afternoon     Weekday              3.0
# 476               NaN     Evening     Weekday              NaN
# 584               NaN       Night     Weekday              4.0
# 641               NaN     Evening     Weekday              4.0
# 647               NaN     Evening     Weekday              2.0
# 725               NaN     Morning     Weekday              1.0
# 734               NaN     Morning     Weekend              1.0
# 770               NaN   Afternoon     Weekday              1.0
# 774               NaN     Evening     Weekday              1.0
# 796               NaN     Evening     Weekday              NaN
# 813               NaN     Morning     Weekday              3.0
# 822               NaN   Afternoon     Weekday              1.0
# 830               NaN       Night     Weekday              3.0
# 839               NaN     Morning     Weekday              3.0
# 845               NaN     Morning     Weekday              4.0
# 846               NaN     Morning     Weekend              4.0
# 872               NaN   Afternoon         NaN              4.0
# 939               NaN     Morning     Weekday              2.0
# 943               NaN     Evening     Weekend              1.0
# 961               NaN   Afternoon     Weekday              2.0
# 970               NaN     Morning     Weekday              4.0
# 993               NaN     Morning     Weekday              3.0
#
#     Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 4                 High   Clear       2.93         0.63             0.32
# 10                 NaN   Clear       2.40         0.58             0.43
# 84              Medium   Clear       3.38         1.50             0.31
# 87              Medium   Clear       3.41         0.57             0.39
# 95              Medium   Clear       3.43         0.91             0.50
# 111                Low   Clear       4.01         1.65             0.17
# 134                Low   Clear       2.55         1.46             0.37
# 137                Low   Clear       4.52         1.38             0.35
# 142             Medium    Rain       2.98         1.24             0.28
# 166               High   Clear       4.11         1.00             0.36
# 191             Medium   Clear       2.47         0.83             0.45
# 196               High   Clear       3.34         1.49             0.27
# 197             Medium   Clear       3.22         1.03             0.38
# 234                Low   Clear       4.03         0.74             0.14
# 269                Low     NaN       4.74         0.99             0.39
# 282                Low   Clear       3.79         1.25             0.45
# 327             Medium   Clear       2.21         0.82             0.23
# 344                Low   Clear       4.62         1.86             0.43
# 357             Medium    Rain       2.03         0.91             0.19
# 366             Medium   Clear       4.20         1.09             0.18
# 401                Low   Clear       3.63         0.80             0.19
# 404               High    Rain       2.30         0.89             0.12
# 417                Low   Clear       4.00         1.87             0.15
# 424               High   Clear        NaN         1.42             0.48
# 428             Medium    Rain       3.84         1.55             0.41
# 438                Low    Rain       2.72         1.25             0.24
# 439             Medium     NaN       2.84         0.97             0.29
# 446             Medium   Clear       3.02         0.70             0.35
# 470               High   Clear       4.37         0.80             0.49
# 476                Low   Clear       2.15         1.62             0.47
# 584                Low   Clear       2.73         1.47             0.37
# 641                Low   Clear       3.08         0.70             0.38
# 647             Medium    Rain       3.46         0.83             0.47
# 725             Medium   Clear       3.88         1.96             0.32
# 734                Low   Clear       3.14          NaN             0.14
# 770             Medium   Clear       3.05         0.98             0.24
# 774             Medium   Clear       3.77         1.15             0.31
# 796                NaN   Clear       3.05         0.74             0.35
# 813               High    Snow       2.81         1.04             0.34
# 822             Medium   Clear       3.64         1.22             0.18
# 830                Low   Clear       2.11         0.82             0.40
# 839                Low   Clear       2.86         1.30             0.41
# 845                Low   Clear       2.22         0.90             0.40
# 846             Medium   Clear       2.82         1.18             0.42
# 872                Low   Clear       4.81         0.65             0.26
# 939                Low    Rain       3.59         0.69             0.27
# 943                Low    Snow       2.10         1.47             0.27
# 961             Medium   Clear       4.06         1.05             0.46
# 970               High   Clear       3.97         1.73             0.19
# 993             Medium   Clear       2.65         1.35              NaN
#
#      Trip_Duration_Minutes  Trip_Price
# 4                    22.64     15.6180
# 10                   26.34     14.8920
# 84                   58.31     45.8161
# 87                   92.72     57.9476
# 95                   67.43     60.0770
# 111                 109.77     37.3559
# 134                  38.26     85.6182
# 137                  57.56     73.5870
# 142                  36.68     44.7092
# 166                  86.31     51.9016
# 191                  80.70     76.1018
# 196                 115.73     89.0764
# 197                  72.79     77.1890
# 234                  49.37     18.7636
# 269                  24.57     29.5584
# 282                  40.52     46.2740
# 327                  42.84     37.4586
# 344                   7.19     45.8975
# 357                  12.42     31.4168
# 366                    NaN     66.1816
# 401                 109.95     60.7045
# 404                  74.77     26.1176
# 417                 100.36     51.0310
# 424                  23.11     19.2572
# 428                  19.20     39.9065
# 438                  49.77     59.1773
# 439                  41.04     19.5819
# 446                  94.88     70.7450
# 470                  18.39     14.6611
# 476                  42.81     29.7551
# 584                  42.88     65.6944
# 641                  27.81     25.3938
# 647                  51.82     56.2678
# 725                 111.65    122.4180
# 734                  89.47     34.4316
# 770                    NaN     19.0904
# 774                  87.74     77.0499
# 796                 105.71     74.5843
# 813                    NaN     66.8568
# 822                  75.87     38.4514
# 830                  85.00     45.9582
# 839                  58.01     68.2181
# 845                 119.82     69.3360
# 846                  91.53     47.3750
# 872                  10.76     28.7716
# 939                  87.25     47.3300
# 943                  48.69     76.4865
# 961                   7.26     39.4771
# 970                  58.48     73.0708
# 993                  25.61     55.3348

# %%
df['Trip_Distance_km'].fillna(df['Trip_Distance_km'].mode(), inplace=True)

# %%
df.describe()
# Out:
#        Trip_Distance_km  Passenger_Count   Base_Fare  Per_Km_Rate  \
# count        951.000000       950.000000  950.000000   950.000000
# mean          27.056424         2.476842    3.502989     1.233316
# std           19.899587         1.102249    0.870162     0.429816
# min            1.230000         1.000000    2.010000     0.500000
# 25%           12.635000         1.250000    2.730000     0.860000
# 50%           25.790000         2.000000    3.520000     1.220000
# 75%           38.390000         3.000000    4.260000     1.610000
# max          146.067047         4.000000    5.000000     2.000000
#
#        Per_Minute_Rate  Trip_Duration_Minutes  Trip_Price
# count       950.000000             950.000000  951.000000
# mean          0.292916              62.118116   56.874773
# std           0.115592              32.154406   40.469791
# min           0.100000               5.010000    6.126900
# 25%           0.190000              35.882500   33.742650
# 50%           0.290000              61.860000   50.074500
# 75%           0.390000              89.055000   69.099350
# max           0.500000             119.840000  332.043689

# %%
df['Passenger_Count'].fillna(df['Passenger_Count'].mode(), inplace=True)
df['Base_Fare'].fillna(df['Base_Fare'].mode(), inplace=True)
df['Per_Km_Rate'].fillna(df['Per_Km_Rate'].mode(), inplace=True)
df['Per_Minute_Rate'].fillna(df['Per_Minute_Rate'].mode(), inplace=True)
df['Per_Minute_Rate'].fillna(df['Per_Minute_Rate'].mode(), inplace=True)
df['Trip_Duration_Minutes'].fillna(df['Trip_Duration_Minutes'].mode(), inplace=True)
df['Trip_Price'].fillna(df['Trip_Price'].mode(), inplace=True)

# %%
df.describe()
# Out:
#        Trip_Distance_km  Passenger_Count   Base_Fare  Per_Km_Rate  \
# count        951.000000       950.000000  950.000000   950.000000
# mean          27.056424         2.476842    3.502989     1.233316
# std           19.899587         1.102249    0.870162     0.429816
# min            1.230000         1.000000    2.010000     0.500000
# 25%           12.635000         1.250000    2.730000     0.860000
# 50%           25.790000         2.000000    3.520000     1.220000
# 75%           38.390000         3.000000    4.260000     1.610000
# max          146.067047         4.000000    5.000000     2.000000
#
#        Per_Minute_Rate  Trip_Duration_Minutes  Trip_Price
# count       950.000000             950.000000  998.000000
# mean          0.292916              62.118116   56.785331
# std           0.115592              32.154406   40.374044
# min           0.100000               5.010000    6.126900
# 25%           0.190000              35.882500   33.557825
# 50%           0.290000              61.860000   49.776500
# 75%           0.390000              89.055000   69.146575
# max           0.500000             119.840000  332.043689

# %%
df['Time_of_Day'].fillna(df['Time_of_Day'].mode(), inplace=True)
df['Day_of_Week'].fillna(df['Day_of_Week'].mode(), inplace=True)
df['Traffic_Conditions'].fillna(df['Traffic_Conditions'].mode(), inplace=True)
df['Weather'].fillna(df['Weather'].mode(), inplace=True)

# %%
df
# Out:
#      Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 0               19.35     Morning     Weekday              3.0
# 1               47.59   Afternoon     Weekday              1.0
# 2               36.87     Evening     Weekend              1.0
# 3               30.33     Evening     Weekday              4.0
# 4               13.64     Evening     Weekday              3.0
# ..                ...         ...         ...              ...
# 995              5.49   Afternoon     Weekend              4.0
# 996             45.95       Night     Weekday              4.0
# 997              7.70     Morning     Weekday              3.0
# 998             47.56     Morning     Weekday              1.0
# 999             22.85     Morning     Weekend              3.0
#
#     Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                  Low   Clear       3.56         0.80             0.32
# 1                 High   Clear        NaN         0.62             0.43
# 2                 High   Clear       2.70         1.21             0.15
# 3                  Low     NaN       3.48         0.51             0.15
# 4                 High   Clear       2.93         0.63             0.32
# ..                 ...     ...        ...          ...              ...
# 995             Medium   Clear       2.39         0.62             0.49
# 996             Medium   Clear       3.12         0.61              NaN
# 997                Low    Rain       2.08         1.78              NaN
# 998                Low   Clear       2.67         0.82             0.17
# 999             Medium   Clear       4.34          NaN             0.23
#
#      Trip_Duration_Minutes  Trip_Price
# 0                    53.82     36.2624
# 1                    40.57      6.4729
# 2                    37.27     52.9032
# 3                   116.81     36.4698
# 4                    22.64     15.6180
# ..                     ...         ...
# 995                  58.39     34.4049
# 996                  61.96     62.1295
# 997                  54.18     33.1236
# 998                 114.94     61.2090
# 999                  29.69     45.4437
#
# [1000 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %% [markdown]
# To find The correlation

# %%
df[['Trip_Distance_km', 'Passenger_Count', 'Base_Fare','Per_Km_Rate', 'Per_Minute_Rate', 'Trip_Duration_Minutes', 'Trip_Price']].corr()
# Out:
#                        Trip_Distance_km  Passenger_Count  Base_Fare  \
# Trip_Distance_km               1.000000        -0.048734   0.032698
# Passenger_Count               -0.048734         1.000000   0.022932
# Base_Fare                      0.032698         0.022932   1.000000
# Per_Km_Rate                   -0.015961         0.030213   0.003092
# Per_Minute_Rate               -0.026082         0.034068  -0.019150
# Trip_Duration_Minutes         -0.021163         0.022845   0.012035
# Trip_Price                     0.822228        -0.018900   0.032344
#
#                        Per_Km_Rate  Per_Minute_Rate  Trip_Duration_Minutes  \
# Trip_Distance_km         -0.015961        -0.026082              -0.021163
# Passenger_Count           0.030213         0.034068               0.022845
# Base_Fare                 0.003092        -0.019150               0.012035
# Per_Km_Rate               1.000000         0.029241               0.027199
# Per_Minute_Rate           0.029241         1.000000              -0.024230
# Trip_Duration_Minutes     0.027199        -0.024230               1.000000
# Trip_Price                0.256275         0.124636               0.201130
#
#                        Trip_Price
# Trip_Distance_km         0.822228
# Passenger_Count         -0.018900
# Base_Fare                0.032344
# Per_Km_Rate              0.256275
# Per_Minute_Rate          0.124636
# Trip_Duration_Minutes    0.201130
# Trip_Price               1.000000

# %%
sns.scatterplot(x='Trip_Distance_km',y='Trip_Price',data=df)
# Out:
# <Axes: xlabel='Trip_Distance_km', ylabel='Trip_Price'>

# %%
X = df[["Trip_Distance_km", "Per_Km_Rate", "Trip_Duration_Minutes"]]
y = df['Trip_Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=9)

# %% [markdown]
# In this code The standarization appply

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train[['Trip_Distance_km', 'Per_Km_Rate', 'Trip_Duration_Minutes']])
X_test_scaled = scaler.transform(X_test[['Trip_Distance_km', 'Per_Km_Rate', 'Trip_Duration_Minutes']])

# %%
model = LinearRegression()

# %%
model.fit(X_train_scaled, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 model.fit(X_train_scaled, y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:609, in LinearRegression.fit(self, X, y, sample_weight)
#     605 n_jobs_ = self.n_jobs
#     607 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 609 X, y = self._validate_data(
#     610     X,
#     611     y,
#     612     accept_sparse=accept_sparse,
#     613     y_numeric=True,
#     614     multi_output=True,
#     615     force_writeable=True,
#     616 )
#     618 has_sw = sample_weight is not None
#     619 if has_sw:
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1301, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1296         estimator_name = _check_estimator_name(estimator)
#    1297     raise ValueError(
#    1298         f"{estimator_name} requires y to be passed, but the target y is None"
#    1299     )
# -> 1301 X = check_array(
#    1302     X,
#    1303     accept_sparse=accept_sparse,
#    1304     accept_large_sparse=accept_large_sparse,
#    1305     dtype=dtype,
#    1306     order=order,
#    1307     copy=copy,
#    1308     force_writeable=force_writeable,
#    1309     force_all_finite=force_all_finite,
#    1310     ensure_2d=ensure_2d,
#    1311     allow_nd=allow_nd,
#    1312     ensure_min_samples=ensure_min_samples,
#    1313     ensure_min_features=ensure_min_features,
#    1314     estimator=estimator,
#    1315     input_name="X",
#    1316 )
#    1318 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1320 check_consistent_length(X, y)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1064, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1058     raise ValueError(
#    1059         "Found array with dim %d. %s expected <= 2."
#    1060         % (array.ndim, estimator_name)
#    1061     )
#    1063 if force_all_finite:
# -> 1064     _assert_all_finite(
#    1065         array,
#    1066         input_name=input_name,
#    1067         estimator_name=estimator_name,
#    1068         allow_nan=force_all_finite == "allow-nan",
#    1069     )
#    1071 if copy:
#    1072     if _is_numpy_namespace(xp):
#    1073         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:123, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     120 if first_pass_isfinite:
#     121     return
# --> 123 _assert_all_finite_element_wise(
#     124     X,
#     125     xp=xp,
#     126     allow_nan=allow_nan,
#     127     msg_dtype=msg_dtype,
#     128     estimator_name=estimator_name,
#     129     input_name=input_name,
#     130 )
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:172, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     155 if estimator_name and input_name == "X" and has_nan_error:
#     156     # Improve the error message on how to handle missing values in
#     157     # scikit-learn.
#     158     msg_err += (
#     159         f"\n{estimator_name} does not accept missing values"
#     160         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     170         "#estimators-that-handle-nan-values"
#     171     )
# --> 172 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# LinearRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
y_pred = model.predict(X_test_scaled)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 y_pred = model.predict(X_test_scaled)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:283, in LinearModel._decision_function(self, X)
#     282 def _decision_function(self, X):
# --> 283     check_is_fitted(self)
#     285     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     286     coef_ = self.coef_
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1661, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1658     raise TypeError("%s is not an estimator instance." % (estimator))
#    1660 if not _is_fitted(estimator, attributes, all_or_any):
# -> 1661     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This LinearRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
# Model Evaluation
# Predicting on test data

# Calculating performance metrics
mse = mean_squared_error(y_test, y_pred)
# rmse = np.sqrt('mse')

rmse = np.sqrt(mse)

# print("\nModel Performance:")
print(f"Mean Squared Error: {mse}")
# print(f"R-squared: {r2}")
print(f"RMSE:{rmse}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 5
#       1 # Model Evaluation
#       2 # Predicting on test data
#       3
#       4 # Calculating performance metrics
# ----> 5 mse = mean_squared_error(y_test, y_pred)
#       6 # rmse = np.sqrt('mse')
#       8 rmse = np.sqrt(mse)
#
# NameError: name 'y_pred' is not defined

# %%
residuals_test = y_test - y_pred

plt.scatter(y_pred, residuals_test, color='purple', alpha=0.6)
plt.axhline(y=0, color='red', linestyle='dashed')  
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot for Multiple Regression")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 residuals_test = y_test - y_pred
#       3 plt.scatter(y_pred, residuals_test, color='purple', alpha=0.6)
#       4 plt.axhline(y=0, color='red', linestyle='dashed')
#
# NameError: name 'y_pred' is not defined

# %%
r2 = r2_score(y_test, y_pred)  # Use actual & predicted values
print("R² Score:", r2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 r2 = r2_score(y_test, y_pred)  # Use actual & predicted values
#       2 print("R² Score:", r2)
#
# NameError: name 'y_pred' is not defined

# %%
y_predict=model.predict(X)
plt.scatter(y, y_predict, color='blue', label='Actual vs Predicted')

plt.plot([min(y), max(y)], [min(y), max(y)], color='red', linestyle='dashed', label='Perfect Fit')

plt.xlabel('Actual Trip Price')
plt.ylabel('Predicted Trip Price')
plt.title('Multiple Regression: Actual vs. Predicted')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 y_predict=model.predict(X)
#       2 plt.scatter(y, y_predict, color='blue', label='Actual vs Predicted')
#       4 plt.plot([min(y), max(y)], [min(y), max(y)], color='red', linestyle='dashed', label='Perfect Fit')
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:283, in LinearModel._decision_function(self, X)
#     282 def _decision_function(self, X):
# --> 283     check_is_fitted(self)
#     285     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     286     coef_ = self.coef_
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1661, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1658     raise TypeError("%s is not an estimator instance." % (estimator))
#    1660 if not _is_fitted(estimator, attributes, all_or_any):
# -> 1661     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This LinearRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.
